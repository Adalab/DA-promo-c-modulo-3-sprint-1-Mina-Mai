# %% [markdown]
# ## Pair Programming - Regresión lineal 7
#
# ### ANOVA
#
# ---

# %%
# Tratamiento de datos
import pandas as pd
import numpy as np

# Estadísticos
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Configuración warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Abrimos nuestro df.

# %%
df_estandarizado= pd.read_csv('../archivos/metro_C.csv', index_col=0)

# %%
df_estandarizado.head(2)
# Out:
#    index        date      time weekday holiday_cat  traffic_volume  \
# 0      0  2012-10-02  09:00:00  martes          no            5546
# 1      1  2012-10-02  10:00:00  martes          no            4517
#
#    traffic_box    temp_c   snow_1h
# 0   544.504895  0.552310 -0.027233
# 1   472.646491  0.637259 -0.027233

# %% [markdown]
# ### 2. Inicializamos la ANOVA

# %%
lm = ols("traffic_box ~ temp_c + weekday + holiday_cat + snow_1h + time", data=df_estandarizado).fit()

# %%
sm.stats.anova_lm(lm)
# Out:
#                   df        sum_sq       mean_sq             F         PR(>F)
# weekday          6.0  6.107391e+07  1.017899e+07   2245.281340   0.000000e+00
# holiday_cat      1.0  3.015261e+06  3.015261e+06    665.106610  1.136118e-145
# time            23.0  1.135052e+09  4.935009e+07  10885.645823   0.000000e+00
# temp_c           1.0  2.838679e+06  2.838679e+06    626.156085  2.596410e-137
# snow_1h          1.0  2.637730e+04  2.637730e+04      5.818307   1.586392e-02
# Residual     48137.0  2.182291e+08  4.533501e+03           NaN            NaN

# %% [markdown]
# ### 3. Sacamos el summary.

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            traffic_box   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     8286.
# Date:                Thu, 26 Jan 2023   Prob (F-statistic):               0.00
# Time:                        17:52:37   Log-Likelihood:            -2.7111e+05
# No. Observations:               48170   AIC:                         5.423e+05
# Df Residuals:                   48137   BIC:                         5.426e+05
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Viendo los resultados concluimos que todas nuestras variables predictoras tienen un valor menor a 0.05, excepto "holiday_cat", y nuestro R-squared tiene un 0.84 de puntuación 😀

# %% [markdown]
# ### 4. Abrimos nuestro df sin estandarizar.

# %%
df_sin_estandarizar= pd.read_csv('../archivos/metro_A.csv', index_col=0)

# %%
df_sin_estandarizar.head(2)
# Out:
#          date weekday      time holiday_cat  temp_c  snow_1h  traffic_volume
# 0  2012-10-02  martes  09:00:00          no   15.13      0.0            5545
# 1  2012-10-02  martes  10:00:00          no   16.21      0.0            4516

# %%
lm = ols("traffic_volume ~ temp_c + weekday + holiday_cat + snow_1h + time", data=df_sin_estandarizar).fit()

# %%
sm.stats.anova_lm(lm)
# Out:
#                   df        sum_sq       mean_sq            F         PR(>F)
# weekday          6.0  1.020540e+10  1.700900e+09  2536.157366   0.000000e+00
# holiday_cat      1.0  4.041737e+08  4.041737e+08   602.650306  2.898363e-132
# time            23.0  1.468912e+11  6.386575e+09  9522.814090   0.000000e+00
# temp_c           1.0  4.380156e+08  4.380156e+08   653.110888  4.252352e-143
# snow_1h          1.0  3.964558e+06  3.964558e+06     5.911424   1.504663e-02
# Residual     48154.0  3.229498e+10  6.706604e+05          NaN            NaN

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         traffic_volume   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     7359.
# Date:                Thu, 26 Jan 2023   Prob (F-statistic):               0.00
# Time:                        18:00:46   Log-Likelihood:            -3.9160e+05
# No. Observations:               48187   AIC:                         7.833e+05
# Df Residuals:                   48154   BIC:                         7.835e+05
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Concluimos que no hay una gran diferencia en los resultados respecto a nuestro df estandarizado, aunque mínimamente nuestro R2 ha bajado a 0.83 y las variable predictora de "holiday_cat" ha mejorado aunque sigue sin ser menor que 0.05.
