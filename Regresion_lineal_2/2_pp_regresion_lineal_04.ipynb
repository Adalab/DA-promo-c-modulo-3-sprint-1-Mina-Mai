# %% [markdown]
# ## Pair Programming - Regresión lineal 4
#
# ### Covarianza y Correlación
#
# ---

# %% [markdown]
# ### 1. Importamos las librerías necesarias.

# %%
# Tratamiento de datos
import numpy as np
import pandas as pd
import random 

# Gráficas
import matplotlib.pyplot as plt
import seaborn as sns

# Medida gráficos
plt.rcParams["figure.figsize"] = (10,8)

# Configuración warnings
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams["figure.figsize"] = (10,10)
sns.set_palette("flare")

# %% [markdown]
# ### 2. Abrimos el archivo con el que vamos a trabajar.

# %%
df = pd.read_csv("../archivos/metro_A.csv", index_col=0)
df.head()
# Out:
#    season  weekday cat_time holiday_cat  temp_c  snow_1h  traffic_volume
# 0  Autumn  tuesday  morning          no   15.13      0.0            5545
# 1  Autumn  tuesday  morning          no   16.21      0.0            4516
# 2  Autumn  tuesday  morning          no   16.43      0.0            4767
# 3  Autumn  tuesday  morning          no   16.98      0.0            5026
# 4  Autumn  tuesday  morning          no   17.99      0.0            4918

# %% [markdown]
# ### 3. Calculamos la covarianza.

# %%
df.cov()
# Out:
#                      temp_c   snow_1h  traffic_volume
# temp_c           161.638754 -0.002165    3.346521e+03
# snow_1h           -0.002165  0.000067    1.195085e-02
# traffic_volume  3346.521299  0.011951    3.947988e+06

# %% [markdown]
# ### 4. Calculamos la correlación de Pearson.

# %%
df.corr()
# Out:
#                   temp_c   snow_1h  traffic_volume
# temp_c          1.000000 -0.020841        0.132475
# snow_1h        -0.020841  1.000000        0.000736
# traffic_volume  0.132475  0.000736        1.000000

# %% [markdown]
# ### 5. Gráfica para comparar variables.

# %%
sns.pairplot(df);

# %% [markdown]
# Según los resultados vemos que en la covarianza entre las variables predictoras es negativa.
#
# Observamos también que al mirar la correlación la fuerza con la que están relacionadas es negativa.
#
# Con el pairplot confirmamos que no hay patrones claros de correlación.
#
# Como vemos que no hay una correlación lineal clara entre nuestras variables vamos a probar hacer la correlación de Spearman, para que nos de unos datos más precisos.

# %% [markdown]
# ### 6. Gráfica para ver la correlación

# %%
mask = np.triu(np.ones_like(df.corr(), dtype=np.bool))

# %%
fig= sns.heatmap(df.corr(), cmap= 'flare', mask= mask, annot=True)
plt.savefig("../graficas/heatmap_df_metro_A.png");
